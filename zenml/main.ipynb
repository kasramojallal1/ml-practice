# %%
! pip install "zenml[server]"
# Out:
# Collecting zenml[server]
#   Downloading zenml-0.67.0-py3-none-any.whl.metadata (21 kB)
# Collecting alembic<1.9.0,>=1.8.1 (from zenml[server])
#   Downloading alembic-1.8.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting bcrypt==4.0.1 (from zenml[server])
#   Downloading bcrypt-4.0.1-cp36-abi3-macosx_10_10_universal2.whl.metadata (9.0 kB)
# Collecting click<8.1.4,>=8.0.1 (from zenml[server])
#   Downloading click-8.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting cloudpickle<3,>=2.0.0 (from zenml[server])
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting distro<2.0.0,>=1.6.0 (from zenml[server])
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: docker<7.2.0,>=7.1.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (7.1.0)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.18 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (3.1.44)
# Collecting importlib_metadata<=7.0.0 (from zenml[server])
#   Downloading importlib_metadata-7.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: packaging>=24.1 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (24.2)
# Collecting passlib<1.8.0,>=1.7.4 (from passlib[bcrypt]<1.8.0,>=1.7.4->zenml[server])
#   Downloading passlib-1.7.4-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: psutil>=5.0.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (6.0.0)
# Collecting pydantic<2.9,>=2.8 (from zenml[server])
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting pydantic-settings (from zenml[server])
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting pymysql<1.2.0,>=1.1.1 (from zenml[server])
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (2.9.0)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (6.0.2)
# Collecting rich>=12.0.0 (from rich[jupyter]>=12.0.0->zenml[server])
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: setuptools in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (75.3.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (2.0.37)
# Collecting sqlalchemy_utils (from zenml[server])
#   Downloading SQLAlchemy_Utils-0.41.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting sqlmodel==0.0.18 (from zenml[server])
#   Downloading sqlmodel-0.0.18-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: Jinja2 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from zenml[server]) (3.1.5)
# Collecting fastapi<=0.110,>=0.100 (from zenml[server])
#   Downloading fastapi-0.110.0-py3-none-any.whl.metadata (25 kB)
# Collecting ipinfo>=4.4.3 (from zenml[server])
#   Downloading ipinfo-5.1.1-py3-none-any.whl.metadata (648 bytes)
# Collecting orjson<3.11.0,>=3.10.0 (from zenml[server])
#   Downloading orjson-3.10.15-cp38-cp38-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (41 kB)
# Collecting pyjwt==2.7.* (from pyjwt[crypto]==2.7.*; extra == "server"->zenml[server])
#   Downloading PyJWT-2.7.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting python-multipart<0.1.0,>=0.0.9 (from zenml[server])
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting secure<0.4.0,>=0.3.0 (from zenml[server])
#   Downloading secure-0.3.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: uvicorn>=0.17.5 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server]) (0.33.0)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]==2.7.*; extra == "server"->zenml[server])
#   Downloading cryptography-44.0.0-cp37-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Requirement already satisfied: Mako in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from alembic<1.9.0,>=1.8.1->zenml[server]) (1.3.8)
# Requirement already satisfied: importlib-resources in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from alembic<1.9.0,>=1.8.1->zenml[server]) (6.4.5)
# Requirement already satisfied: requests>=2.26.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from docker<7.2.0,>=7.1.0->zenml[server]) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from docker<7.2.0,>=7.1.0->zenml[server]) (2.2.3)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi<=0.110,>=0.100->zenml[server])
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from fastapi<=0.110,>=0.100->zenml[server]) (4.12.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from gitpython<4.0.0,>=3.1.18->zenml[server]) (4.0.12)
# Requirement already satisfied: zipp>=0.5 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from importlib_metadata<=7.0.0->zenml[server]) (3.21.0)
# Requirement already satisfied: cachetools in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipinfo>=4.4.3->zenml[server]) (5.5.0)
# Requirement already satisfied: aiohttp<=4 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipinfo>=4.4.3->zenml[server]) (3.10.11)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from pydantic<2.9,>=2.8->zenml[server]) (0.7.0)
# Collecting pydantic-core==2.20.1 (from pydantic<2.9,>=2.8->zenml[server])
#   Downloading pydantic_core-2.20.1-cp38-cp38-macosx_10_12_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.5 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from python-dateutil<3.0.0,>=2.8.1->zenml[server]) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->rich[jupyter]>=12.0.0->zenml[server])
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from rich>=12.0.0->rich[jupyter]>=12.0.0->zenml[server]) (2.18.0)
# Collecting ipywidgets<9,>=7.5.1 (from rich[jupyter]>=12.0.0->zenml[server])
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from sqlalchemy<3.0.0,>=2.0.0->zenml[server]) (3.1.1)
# Requirement already satisfied: h11>=0.8 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from uvicorn>=0.17.5->uvicorn[standard]>=0.17.5; extra == "server"->zenml[server]) (0.14.0)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server])
#   Downloading httptools-0.6.4-cp38-cp38-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server])
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server])
#   Downloading uvloop-0.21.0-cp38-cp38-macosx_10_9_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server])
#   Downloading watchfiles-0.24.0-cp38-cp38-macosx_10_12_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.17.5; extra == "server"->zenml[server])
#   Using cached websockets-13.1-cp38-cp38-macosx_10_9_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from Jinja2->zenml[server]) (2.1.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (5.0.1)
# Collecting cffi>=1.12 (from cryptography>=3.4.0->pyjwt[crypto]==2.7.*; extra == "server"->zenml[server])
#   Downloading cffi-1.17.1-cp38-cp38-macosx_10_9_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.18->zenml[server]) (5.0.2)
# Requirement already satisfied: comm>=0.1.3 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (8.12.2)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server])
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server])
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->rich[jupyter]>=12.0.0->zenml[server])
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from requests>=2.26.0->docker<7.2.0,>=7.1.0->zenml[server]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from requests>=2.26.0->docker<7.2.0,>=7.1.0->zenml[server]) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from requests>=2.26.0->docker<7.2.0,>=7.1.0->zenml[server]) (2024.12.14)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from starlette<0.37.0,>=0.36.3->fastapi<=0.110,>=0.100->zenml[server]) (4.5.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi<=0.110,>=0.100->zenml[server]) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from anyio<5,>=3.4.0->starlette<0.37.0,>=0.36.3->fastapi<=0.110,>=0.100->zenml[server]) (1.2.2)
# Collecting pycparser (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]==2.7.*; extra == "server"->zenml[server])
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: backcall in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.0)
# Requirement already satisfied: decorator in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.1.7)
# Requirement already satisfied: pickleshare in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (3.0.48)
# Requirement already satisfied: stack-data in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (4.9.0)
# Requirement already satisfied: appnope in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.1.4)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from yarl<2.0,>=1.12.0->aiohttp<=4->ipinfo>=4.4.3->zenml[server]) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (3.0.0)
# Requirement already satisfied: pure-eval in /opt/miniconda3/envs/ml-practice/lib/python3.8/site-packages (from stack-data->ipython>=6.1.0->ipywidgets<9,>=7.5.1->rich[jupyter]>=12.0.0->zenml[server]) (0.2.3)
# Downloading bcrypt-4.0.1-cp36-abi3-macosx_10_10_universal2.whl (473 kB)
# Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Downloading sqlmodel-0.0.18-py3-none-any.whl (26 kB)
# Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
# Downloading click-8.1.3-py3-none-any.whl (96 kB)
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
# Downloading importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Downloading ipinfo-5.1.1-py3-none-any.whl (24 kB)
# Downloading orjson-3.10.15-cp38-cp38-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (249 kB)
# Downloading passlib-1.7.4-py2.py3-none-any.whl (525 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.6/525.6 kB 3.5 MB/s eta 0:00:00
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Downloading pydantic_core-2.20.1-cp38-cp38-macosx_10_12_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 4.5 MB/s eta 0:00:0000:0100:01
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading secure-0.3.0-py3-none-any.whl (9.6 kB)
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Downloading SQLAlchemy_Utils-0.41.2-py3-none-any.whl (93 kB)
# Downloading zenml-0.67.0-py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 7.1 MB/s eta 0:00:00a 0:00:01
# Downloading cryptography-44.0.0-cp37-abi3-macosx_10_9_universal2.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 6.9 MB/s eta 0:00:00a 0:00:01
# Downloading httptools-0.6.4-cp38-cp38-macosx_10_9_universal2.whl (202 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
# Downloading uvloop-0.21.0-cp38-cp38-macosx_10_9_x86_64.whl (797 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.0/798.0 kB 6.3 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp38-cp38-macosx_10_12_x86_64.whl (375 kB)
# Using cached websockets-13.1-cp38-cp38-macosx_10_9_x86_64.whl (155 kB)
# Downloading cffi-1.17.1-cp38-cp38-macosx_10_9_x86_64.whl (182 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 7.0 MB/s eta 0:00:00a 0:00:01
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: passlib, widgetsnbextension, websockets, uvloop, secure, python-multipart, python-dotenv, pymysql, pyjwt, pydantic-core, pycparser, orjson, mdurl, jupyterlab-widgets, importlib_metadata, httptools, distro, cloudpickle, click, bcrypt, watchfiles, starlette, sqlalchemy_utils, pydantic, markdown-it-py, cffi, alembic, sqlmodel, rich, pydantic-settings, ipywidgets, fastapi, cryptography, ipinfo, zenml
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.2
#     Uninstalling pydantic_core-2.27.2:
#       Successfully uninstalled pydantic_core-2.27.2
#   Attempting uninstall: importlib_metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.1
#     Uninstalling cloudpickle-3.1.1:
#       Successfully uninstalled cloudpickle-3.1.1
#   Attempting uninstall: click
#     Found existing installation: click 8.1.8
#     Uninstalling click-8.1.8:
#       Successfully uninstalled click-8.1.8
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.41.3
#     Uninstalling starlette-0.41.3:
#       Successfully uninstalled starlette-0.41.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.5
#     Uninstalling pydantic-2.10.5:
#       Successfully uninstalled pydantic-2.10.5
#   Attempting uninstall: alembic
#     Found existing installation: alembic 1.14.1
#     Uninstalling alembic-1.14.1:
#       Successfully uninstalled alembic-1.14.1
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.115.6
#     Uninstalling fastapi-0.115.6:
#       Successfully uninstalled fastapi-0.115.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.2 which is incompatible.
# Successfully installed alembic-1.8.1 bcrypt-4.0.1 cffi-1.17.1 click-8.1.3 cloudpickle-2.2.1 cryptography-44.0.0 distro-1.9.0 fastapi-0.110.0 httptools-0.6.4 importlib_metadata-7.0.0 ipinfo-5.1.1 ipywidgets-8.1.5 jupyterlab-widgets-3.0.13 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.10.15 passlib-1.7.4 pycparser-2.22 pydantic-2.8.2 pydantic-core-2.20.1 pydantic-settings-2.7.1 pyjwt-2.7.0 pymysql-1.1.1 python-dotenv-1.0.1 python-multipart-0.0.20 rich-13.9.4 secure-0.3.0 sqlalchemy_utils-0.41.2 sqlmodel-0.0.18 starlette-0.36.3 uvloop-0.21.0 watchfiles-0.24.0 websockets-13.1 widgetsnbextension-4.0.13 zenml-0.67.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
import zenml

print(zenml.__version__)
# Out:
# 0.67.0

# %%
! rm -rf .zen
! zenml init
# Out:
# Initializing the ZenML global configuration version to 0.67.0
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# Creating database tables
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠸ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠴ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠧ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# Creating default workspace 'default' ...
# Creating default stack in workspace default...
# ⠏ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠙ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠸ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# Setting the global active workspace to 'default'.
# Setting the global active stack to default.
# Setting the repo active workspace to 'default'.
# Setting the repo active stack to default.
# ⠴ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠧ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠇ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠏ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠙ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠸ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠴ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠧ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠇ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠙ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠸ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠴ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠧ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠇ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠏ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠙ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠸ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠴ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠧ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠏ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠸ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠴ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠧ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠇ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠏ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠙ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠸ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠧ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠇ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠏ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠙ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠸ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠴ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠧ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠇ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠏ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠋ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠙ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠹ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠼ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠴ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# Reloading configuration file /Users/kasra/Codes/ml-practice/zenml/.zen/config.yaml
# ZenML repository initialized at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
# ⠦ Initializing ZenML repository at /Users/kasra/Codes/ml-practice/zenml.
#
# The local active stack was initialized to 'default'. This local configuration
# will only take effect when you're running ZenML from the initialized repository
# root, or from a subdirectory. For more information on repositories and
# configurations, please visit
# https://docs.zenml.io/user-guide/starter-guide/understand-stacks.

# %%
import numpy as np
from sklearn.base import ClassifierMixin
from sklearn.svm import SVC
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

def train_test() -> None:
    """Train and test a Scikit-learn SVC classifier on digits"""
    digits = load_digits()
    data = digits.images.reshape((len(digits.images), -1))
    X_train, X_test, y_train, y_test = train_test_split(
        data, digits.target, test_size=0.2, shuffle=False
    )

    model = SVC(gamma=0.001)
    model.fit(X_train, y_train)
    test_acc = model.score(X_test, y_test)
    print(f"Test accuracy: {test_acc}")

train_test()
# Out:
# Test accuracy: 0.9583333333333334
